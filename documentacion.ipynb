# %%
import pandas as pd

# Crear CSV de ejemplo para practicar
datos_ejemplo = pd.DataFrame({
    'nombre': ['Producto A', 'Producto B', 'Producto C'],
    'precio': [100, 200, 150],
    'cantidad': [50, 30, 40],
    'categoria': ['Electrónica', 'Hogar', 'Electrónica']
})
datos_ejemplo.to_csv('ejemplo_ventas.csv', index=False)

# Leer el archivo
df = pd.read_csv('ejemplo_ventas.csv')
print(df)
print(f"\nForma: {df.shape}")
print(f"\nColumnas: {df.columns.tolist()}")
